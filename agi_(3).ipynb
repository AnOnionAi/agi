# %% [markdown]
# Clone the Repo

# %%
# !git clone https://github.com/ZetiAi/agi.git
# Out:
# Cloning into 'agi'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 46 (delta 11), reused 39 (delta 10), pack-reused 0
# Receiving objects: 100% (46/46), 566.79 KiB | 4.17 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %% [markdown]
# Move to the Directory

# %%
# %cd /content/agi
# Out:
# /content/agi

# %% [markdown]
# Install Poetry

# %%
# !sudo apt update
# !sudo apt install pipx
# !pipx ensurepath
# !pipx install poetry
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [633 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,304 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %% [markdown]
# Train the Model

# %%
import os
if 'COLAB_TPU_ADDR' in os.environ:
  print("Connected to a TPU.")
else:
  print("TPU not available.")
# Out:
# Connected to a TPU.

# %%
# !/root/.local/bin/poetry env use 3.10
# Out:
# Creating virtualenv agi-cF9WszDc-py3.10 in /root/.cache/pypoetry/virtualenvs
# Using virtualenv: /root/.cache/pypoetry/virtualenvs/agi-cF9WszDc-py3.10

# %%
# !/root/.local/bin/poetry install --no-root
# Out:
# Installing dependencies from lock file
# ...
#
# Package operations: 60 installs, 0 updates, 0 removals
#
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Downloading... 0%
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Downloading... 10%
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Downloading... 60%
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Downloading... 100%
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Installing...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101)
#   • Installing filelock (3.13.1): Pending...
#   • Installing frozenlist (1.4.0): Pending...
#   • Installing idna (3.6): Pending...
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing multidict (6.0.4): Pending...
#   • Installing frozenlist (1.4.0): Pending...
#   • Installing idna (3.6): Pending...
#   • Installing markupsafe (2.1.3): Pending...
# ...

# %%
# !/root/.local/bin/poetry add torch-xla
# Out:
# Using version ^2.1.0 for torch-xla
#
# Updating dependencies
# Resolving dependencies... (32.3s)
#
# Package operations: 11 installs, 1 update, 0 removals
#
#   • Downgrading protobuf (4.23.4 -> 3.20.3): Pending...
#   • Installing pyparsing (3.1.1): Pending...
#   • Installing pyparsing (3.1.1): Downloading... 0%
#   • Installing pyparsing (3.1.1): Downloading... 0%
#   • Downgrading protobuf (4.23.4 -> 3.20.3): Downloading... 0%
#   • Installing pyparsing (3.1.1): Downloading... 0%
#   • Installing pyparsing (3.1.1): Downloading... 100%
#   • Installing pyparsing (3.1.1): Installing...
#   • Installing pyparsing (3.1.1)
#   • Installing pyparsing (3.1.1)
#   • Downgrading protobuf (4.23.4 -> 3.20.3): Downloading... 20%
#   • Installing pyparsing (3.1.1)
#   • Installing pyparsing (3.1.1)
#   • Downgrading protobuf (4.23.4 -> 3.20.3): Downloading... 100%
#   • Installing pyparsing (3.1.1)
#   • Installing pyparsing (3.1.1)
# ...

# %%
# !/root/.local/bin/poetry run python src/main.py train
# Out:
# Vocabulary Size: 100232
# WARNING:root:PJRT is now the default runtime. For more information, see https://github.com/pytorch/xla/blob/master/docs/pjrt.md
# WARNING:root:Defaulting to PJRT_DEVICE=CPU
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: tb_logs/my_model
